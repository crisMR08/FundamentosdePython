# %% [markdown]
# # NOTEBOOK 03 — Condicionales, Ciclos y Listas
#
# ## Fundamentos de Python | UMCA
# ## Profesor: Ing. Andrés Mena Abarca
#
# ### <mark>**Nombre del estudiante: Cristopher Mora Rodríguez**</mark>
#
# ---
#
# ### Acerca de este notebook
#
# En las siguientes fases construimos paso a paso un sistema de registro de notas
# para un salón de clase. Cada fase agrega una herramienta nueva de Python.
#
# | Fase | Tema | Herramienta principal |
# |------|------|------------------------|
# | 0 | Conexión con la semana anterior | Repaso `if-elif-else` |
# | 1 | Condicionales robustos | `if-elif-else` + `try-except` |
# | 2 | Bucle `for` con acumuladores | `for`, `range`, `enumerate` |
# | 3 | Bucle `while` con menú | `while`, `break`, `continue` |
# | 4 | Listas y sus métodos | `append`, `sort`, slicing, CSV |
# | 5 | Introducción a funciones | `def`, parámetros, `return` |

# %% [markdown]
# ---
#
# ## Fase 0 — Conexión con la semana anterior
#
# ### Repaso: condicionales
#
# La semana pasada trabajamos con `if-elif-else`. Recuerda la estructura básica:
#
# ```python
# if condición:
#     # se ejecuta si la condición es True
# elif otra_condición:
#     # se ejecuta si la primera es False pero esta es True
# else:
#     # se ejecuta si ninguna condición anterior fue True
# ```
#
# **Ejemplo revisado con notas:**

# %%
# Verificar si una nota aprueba o reprueba
nota = 75

if nota >= 70:
    estado = "Aprobado"
else:
    estado = "Reprobado"

print(f"Nota: {nota} → {estado}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\debugpy\_vendored\pydevd\pydevd.py:1394, in PyDB.apply_files_filter(self, frame, original_filename, force_check_project_scope)
#    1393 try:
# -> 1394     return self._apply_filter_cache[cache_key]
#    1395 except KeyError:
#
# KeyError: (721, 'C:\\Users\\CRIS\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python313\\site-packages\\ipykernel\\iostream.py', True, <code object write at 0x000001E8167E85A0, file "C:\Users\CRIS\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ipykernel\iostream.py", line 721>)
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\debugpy\_vendored\pydevd\pydevd.py:1359, in PyDB._exclude_by_filter(self, frame, absolute_filename)
#    1358 try:
# -> 1359     return self._exclude_by_filter_cache[cache_key]
#    1360 except KeyError:
#
# KeyError: ('C:\\Users\\CRIS\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python313\\site-packages\\ipykernel\\iostream.py', 'write', 721)
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 9
#       6 else:
#       7     estado = "Reprobado"
# ----> 9 print(f"Nota: {nota} → {estado}")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\IPython\core\interactiveshell.py:3053, in InteractiveShell._tee.<locals>.write(data, *args, **kwargs)
#    3051 def write(data, *args, **kwargs):
#    3052     """Write data to both the original destination and the capture dictionary."""
# -> 3053     result = original_write(data, *args, **kwargs)
#    3054     if any(
#    3055         [
#    3056             self.display_pub.is_publishing,
#    (...)   3059         ]
#    3060     ):
#    3061         return result
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ipykernel\iostream.py:721, in OutStream.write(self, string)
#     713                     return
#     715             self.session.send(
#     716                 self.pub_thread,
#     717                 msg,
#     718                 ident=self.topic,
#     719             )
# --> 721 def write(self, string: str) -> int | None:  # type:ignore[override]
#     722     """Write to current stream after encoding if necessary
#     723
#     724     Returns
#    (...)    728
#     729     """
#     730     parent = self.parent_header
#
# File <stringsource>:69, in cfunc.to_py.__Pyx_CFunc_893235__29_pydevd_sys_monitoring_cython_object__lParen__etc_to_py_4code_18instruction_offset.wrap()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1713, in _pydevd_sys_monitoring_cython._start_method_event()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:634, in _pydevd_sys_monitoring_cython._get_func_code_info()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\debugpy\_vendored\pydevd\pydevd.py:1407, in PyDB.apply_files_filter(self, frame, original_filename, force_check_project_scope)
#    1405 if self._exclude_filters_enabled:
#    1406     absolute_filename = pydevd_file_utils.absolute_path(original_filename)
# -> 1407     exclude_by_filter = self._exclude_by_filter(frame, absolute_filename)
#    1408     if exclude_by_filter is not None:
#    1409         if exclude_by_filter:
#    1410             # ignore files matching stepping filters
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\debugpy\_vendored\pydevd\pydevd.py:1370, in PyDB._exclude_by_filter(self, frame, absolute_filename)
#    1368     if self._files_filtering.require_module:
#    1369         module_name = frame.f_globals.get("__name__", "")
# -> 1370     cache[cache_key] = self._files_filtering.exclude_by_filter(absolute_filename, module_name)
#    1372 return cache[cache_key]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\debugpy\_vendored\pydevd\_pydevd_bundle\pydevd_filtering.py:322, in FilesFiltering.exclude_by_filter(self, absolute_filename, module_name)
#     320 for exclude_filter in self._exclude_filters:  # : :type exclude_filter: ExcludeFilter
#     321     if exclude_filter.is_path:
# --> 322         if glob_matches_path(absolute_filename, exclude_filter.name):
#     323             return exclude_filter.exclude
#     324     else:
#     325         # Module filter.
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\debugpy\_vendored\pydevd\_pydevd_bundle\pydevd_filtering.py:84, in glob_matches_path(path, pattern, sep, altsep)
#      81     if patterns[0] == "":
#      82         patterns = patterns[1:]
# ---> 84 return _check_matches(patterns, paths)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\debugpy\_vendored\pydevd\_pydevd_bundle\pydevd_filtering.py:57, in _check_matches(patterns, paths)
#      53 elif not fnmatch.fnmatch(path, pattern):
#      54     # Current part doesn't match.
#      55     return False
# ---> 57 return _check_matches(patterns[1:], paths[1:])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\debugpy\_vendored\pydevd\_pydevd_bundle\pydevd_filtering.py:57, in _check_matches(patterns, paths)
#      53 elif not fnmatch.fnmatch(path, pattern):
#      54     # Current part doesn't match.
#      55     return False
# ---> 57 return _check_matches(patterns[1:], paths[1:])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\debugpy\_vendored\pydevd\_pydevd_bundle\pydevd_filtering.py:37, in _check_matches(patterns, paths)
#      34     return False
#      36 pattern = normcase(patterns[0])
# ---> 37 path = normcase(paths[0])
#      39 if not glob.has_magic(pattern):
#      40     if pattern != path:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\debugpy\_vendored\pydevd\pydevd_file_utils.py:349, in normcase(s, NORMCASE_CACHE)
#     345 else:
#     346     _default_normcase = _normcase_linux
# --> 349 def normcase(s, NORMCASE_CACHE={}):
#     350     try:
#     351         return NORMCASE_CACHE[s]
#
# KeyboardInterrupt:

# %% [markdown]
# ### Motivación
#
# Este código funciona para **una** nota. Pero si tenemos 30 estudiantes,
# ¿repetiríamos el `if-else` 30 veces?
#
# **¿Hay una mejor manera?** → Sí: con **bucles** y **listas**.
# Eso es exactamente lo que aprenderemos en esta clase.

# %% [markdown]
# ### <mark>Ejercicio 0.1 — Repaso rápido</mark>
#
# Dado el promedio final de un estudiante (ingresado por teclado), determinamos su resultado:
#
# | Rango | Resultado |
# |-------|-----------|
# | >= 90 | Aprobado con distinción |
# | >= 80 | Aprobado con mérito |
# | >= 70 | Aprobado |
# | < 70  | Reprobado |
#
# Usamos `try-except` para manejar valores no numéricos.

# %%
# Fase 0 — Ejercicio 0.1
# Clasifica el resultado según el promedio final.
# Valida la entrada con try-except.

#Respuesta
try:
    promedio = float(input("ingrese su nota por favor: "))
    if promedio >= 90:
        print("Aprobado con distinción")
    elif promedio >= 80:
        print("Aprobado con merito")
    elif promedio >= 70:
        print("Aprobado")
    else:
        print("Reprobado")
        
except ValueError:
    print("Ingrese un número valido")
# Out:
# Aprobado

# %% [markdown]
# ---
#
# ## Fase 1 — Condicionales robustos
#
# ### 1.1 if-elif-else con rangos
#
# Las escalas de notas usan rangos. Una vez que una condición es `True`,
# Python no evalúa las siguientes, por eso podemos usar `>=` sin `and`:
#
# ```python
# # En lugar de:
# if nota >= 90 and nota <= 100:
#     categoria = "Excelente"
#
# # Podemos escribir (más limpio):
# if nota >= 90:         # implícitamente <= 100 porque los casos superiores ya se descartaron
#     categoria = "Excelente"
# elif nota >= 75:
#     categoria = "Bueno"
# ```
#
# ### 1.2 try-except: validación de entrada
#
# Siempre que el usuario ingrese un valor, puede equivocarse. El patrón estándar del curso:
#
# ```python
# try:
#     nota = float(input("Ingrese la nota: "))
#     # ... código que usa nota ...
# except ValueError:
#     print("❌ Ingrese un número válido.")
# ```
#
# **Ejemplo completo:**

# %%
# Ejemplo: clasificar una nota con try-except
try:
    nota = float(input("Ingrese la nota del estudiante (0–100): "))

    if nota < 0 or nota > 100: #restringe rango de notas válidas de 0-100
        print("⚠️ La nota debe estar entre 0 y 100.")
    elif nota >= 90:
        print(f"Nota {nota:.1f} → Excelente")
    elif nota >= 75:
        print(f"Nota {nota:.1f} → Bueno")
    elif nota >= 60:
        print(f"Nota {nota:.1f} → Suficiente")
    else:
        print(f"Nota {nota:.1f} → Reprobado")

except ValueError:
    print("❌ Ingrese un número válido.")

# %% [markdown]
# ### <mark>Ejercicio 1.1 — Clasificador de notas</mark>
#
# Escribimos un programa que pide una nota y la clasifica:
#
# | Rango | Categoría |
# |-------|-----------|
# | 90 – 100 | Excelente |
# | 75 – 89  | Bueno |
# | 60 – 74  | Suficiente |
# | 0 – 59   | Reprobado |
#
# **Requisitos:**
# - Usamos `try-except` para manejar entradas no numéricas.
# - Si la nota está fuera del rango 0–100, mostramos un mensaje de advertencia.

# %%
# Fase 1 — Ejercicio 1.1
# Clasifica la nota ingresada: Excelente (90-100), Bueno (75-89),
# Suficiente (60-74), Reprobado (<60).
# Valida con try-except y verifica el rango 0-100.

#Respuesta

# %% [markdown]
# ---
#
# ## Fase 2 — Bucle for con acumuladores
#
# ### 2.1 Iterar sobre listas
#
# El bucle `for` recorre cada elemento de una lista, uno por uno:
#
# ```python
# notas = [85, 62, 91, 74, 58]
#
# for nota in notas:
#     print(nota)
# ```
#
# ### 2.2 Acumuladores
#
# Un acumulador es una variable que crece con cada iteración:
#
# ```python
# notas = [85, 62, 91, 74, 58]
# suma = 0          # ← acumulador inicializado en 0
#
# for nota in notas:
#     suma += nota  # suma = suma + nota
#
# promedio = suma / len(notas)
# print(f"Promedio: {promedio:.2f}")
# ```
#
# ### 2.3 enumerate() — índice + valor
#
# `enumerate()` nos da el índice y el valor al mismo tiempo,
# sin necesidad de una variable de conteo manual:
#
# ```python
# notas = [85, 62, 91]
#
# for i, nota in enumerate(notas, start=1):
#     print(f"Estudiante {i}: {nota}")
# ```

# %% [markdown]
# ### <mark>Ejercicio 2.1 — Reporte del salón</mark>
#
# Dada la siguiente lista de notas, usamos un bucle `for` para dos tareas:
#
# **Parte A — Estadísticas del salón:**
# - Calcular el promedio general
# - Contar los estudiantes aprobados (>= 70) y reprobados (< 70)
#
# **Parte B — Lista numerada con `enumerate()`:**
# Mostramos cada nota numerada (comenzando en 1) con su estado:
# ```
# Estudiante  1: 92 → Aprobado
# Estudiante  2: 78 → Aprobado
# Estudiante  3: 65 → Reprobado
# ...
# ```

# %%
# Fase 2 — Ejercicio 2.1
notas = [92, 78, 65, 88, 55, 73, 96, 82, 47, 61, 85, 70, 93, 58, 79]

# Parte A: promedio, aprobados y reprobados
#Respuesta 

#Notas aprobadas
aprobados = 0 #variable acumuladora de notas aprobadas
reprobados = 0  #variable acumuladora de notas reprobadas
suma = 0
for nota in notas:
    suma += nota 
    
    if nota >= 70:
        aprobados += 1
    else:
        reprobados += 1
        
promedio = suma / len(notas)

#Recorrer lista y mostrar
#for x in notas:
    #print(x)
    
print("---Reporte de Notas---")
##print(len(notas)) #tamaño total de la lista 
print(f"Total de estudiantes: {len(notas)}")
print(f"Total de estudiantes aprobados: {aprobados}")
print(f"Total de estudiantes reprobados: {reprobados}")
print(f"Promedio general: {promedio:.2f}")
    
    
# Parte B: lista numerada con enumerate()
#Respuesta
print("\n---Reporte Detallado de Notas")
for i,nota in enumerate( notas,start= 1):
    estado = "aprobado" if nota >= 70 else "Reprobado"
    print(f"Estudiante {i}: {nota} -> {estado}")
# Out:
# ---Reporte de Notas---
# Total de estudiantes: 15
# Total de estudiantes aprobados: 10
# Total de estudiantes reprobados: 5
# Promedio general: 74.80
#
# ---Reporte Detallado de Notas
# Estudiante 1: 92 -> aprobado
# Estudiante 2: 78 -> aprobado
# Estudiante 3: 65 -> Reprobado
# Estudiante 4: 88 -> aprobado
# Estudiante 5: 55 -> Reprobado
# Estudiante 6: 73 -> aprobado
# Estudiante 7: 96 -> aprobado
# Estudiante 8: 82 -> aprobado
# Estudiante 9: 47 -> Reprobado
# Estudiante 10: 61 -> Reprobado
# Estudiante 11: 85 -> aprobado
# Estudiante 12: 70 -> aprobado
# Estudiante 13: 93 -> aprobado
# Estudiante 14: 58 -> Reprobado
# Estudiante 15: 79 -> aprobado

# %% [markdown]
# ---
#
# ## Fase 3 — Bucle while con menú
#
# ### 3.1 Patrón: while True + break
#
# El patrón más común para menús interactivos en Python:
#
# ```python
# while True:
#     opcion = input("Opción: ")
#     if opcion == "0":
#         break     # sale del bucle completamente
#     # procesar otras opciones...
# ```
#
# ### 3.2 break vs continue
#
# | Palabra clave | Efecto |
# |---------------|--------|
# | `break` | **Termina** el bucle completamente |
# | `continue` | **Salta** el resto del ciclo actual y pasa al siguiente |
#
# **Ejemplo contrastado:**

# %%
# Diferencia entre break y continue
numeros = [10, 20, -1, 30, 40]

print("--- Con break ---")
for n in numeros:
    if n < 0:
        print("Número negativo encontrado. Deteniendo el bucle.")
        break
    print(n)

print("\n--- Con continue ---")
for n in numeros:
    if n < 0:
        print("Número negativo encontrado. Saltando.")
        continue
    print(n)

# %% [markdown]
# ### <mark>Ejercicio 3.1 — Menú interactivo de notas</mark>
#
# Completamos el siguiente esqueleto de menú con `while True + break`.
# Cada bloque `#Respuesta` representa la lógica de una opción:
#
# **Requisitos:**
# - Validamos que las notas estén en el rango 0–100 (usamos `try-except`).
# - Si la lista está vacía al pedir el promedio, mostramos un aviso en lugar de un error.
# - Usamos `continue` para volver al menú cuando haya un error de entrada.

# %%
# Fase 3 — Ejercicio 3.1
notas = []

while True:
    print("\n--- Menú de Notas ---")
    print("1. Agregar nota")
    print("2. Ver todas las notas")
    print("3. Ver promedio actual")
    print("4. Salir")

    opcion = input("Opción: ")

    if opcion == "1":
        # Escribimos el código para agregar una nota validada
        pass  # Respuesta

    elif opcion == "2":
        # Mostramos todas las notas o un aviso si la lista está vacía
        pass  # Respuesta

    elif opcion == "3":
        # Calculamos y mostramos el promedio (evitamos división por cero)
        pass  # Respuesta

    elif opcion == "4":
        print("Saliendo del sistema de notas...")
        break

    else:
        print("❌ Opción no válida.")

# %% [markdown]
# ---
#
# ## Fase 4 — Listas y sus métodos
#
# ### 4.1 Métodos principales
#
# ```python
# notas = [85, 62, 91]
#
# notas.append(74)          # agrega al final         → [85, 62, 91, 74]
# notas.insert(0, 99)       # inserta en posición 0   → [99, 85, 62, 91, 74]
# notas.remove(62)          # elimina la 1ª ocurrencia → [99, 85, 91, 74]
# ultima = notas.pop()      # elimina y retorna el último → ultima = 74
# notas.sort()              # ordena ascendente en su lugar
# notas.sort(reverse=True)  # ordena descendente
# ```
#
# ### 4.2 Funciones de colecciones
#
# ```python
# notas = [85, 91, 62, 74, 96]
#
# print(len(notas))   # 5  — cantidad de elementos
# print(sum(notas))   # 408 — suma total
# print(min(notas))   # 62 — valor mínimo
# print(max(notas))   # 96 — valor máximo
# ```
#
# ### 4.3 Slicing — vista previa (Semana 07)
#
# El slicing permite extraer partes de una lista sin modificarla:
#
# ```python
# notas = [96, 91, 85, 74, 62]  # ordenadas de mayor a menor
#
# top3    = notas[:3]   # primeros 3 → [96, 91, 85]
# ultimos = notas[-2:]  # últimos 2  → [74, 62]
# ```
#
# **Ejemplo:**

# %%
# Ejemplo completo: métodos de listas
notas = [85, 62, 91, 74, 58]

# Lista original y estadísticas

print(f"Lista original: {notas}")
#Tamaño, suma, mínimo y máximo
print(f"Tamanio lista: {len(notas)}")
print(f"Suma: {sum(notas)}")
print(f"Minimo: {min(notas)}")
print(f"Maximo: {max(notas)}")


# Ordenar y obtener Top 3
notas.sort() #ordena lista de menor a mayor
print(f"\n Lista Ordenada de Menor a Mayor: {notas}")
notas.sort(reverse=True) #ordena lista de mayor a menor
print(f"\n Lista Ordenada de Mayor a Menor: {notas}")

# Top 3 notas
top3 = notas[0:3] #muestra primeros 3 numeros de la lista
print(f"Top 3: {top3}")
# Out:
# Lista original: [85, 62, 91, 74, 58]
# Tamanio lista: 5
# Suma: 370
# Minimo: 58
# Maximo: 91
#
#  Lista Ordenada de Menor a Mayor: [58, 62, 74, 85, 91]
#
#  Lista Ordenada de Mayor a Menor: [91, 85, 74, 62, 58]
# Top 3: [91, 85, 74]

# %% [markdown]
# ### 4.4 Lectura de un archivo externo
#
# En las Semanas 08–10 aprenderemos a leer JSON y CSV con bibliotecas especializadas.
# Por ahora, usaremos `open()` y un bucle `for` simple:
#
# ```python
# with open("archivo.csv") as archivo:
#     next(archivo)  # saltar la primera línea (encabezado)
#     for linea in archivo:
#         partes = linea.strip().split(",")
#         nombre = partes[0]
#         nota   = float(partes[1])
#         print(f"{nombre}: {nota}")
# ```
#
# El archivo `notas_ejemplo.csv` tiene este formato:
# ```
# nombre,nota
# Ana Pérez,92
# Carlos Mora,78
# ...
# ```
#
# **Ejemplo guiado — leemos el CSV paso a paso:**

# %%
suma  = 0
total = 0
with open("notas_ejemplo.csv") as archivo:
    next(archivo)
    for linea in archivo:
        partes = linea.strip().split(",") #parate el archivo e indica la cantidad de columnas del archivo
        nota   = float(partes[1]) #indica que va a trabajar con la segunda columna (notas)
        nombres = partes[0] #lista de nomnres
        suma  += nota
        total += 1
        if nota >= 90:
            print("Excelente")
        elif nota >= 75:
            print("Bueno")
        elif nota >= 60:
            print("Suficiente")
        else:
            print("Reporobado")
        print(f"Nombre: {nombres } {nota} ")

print(f"Promedio del salón (desde archivo): {suma/total:.2f}")
# Out:
# Excelente
# Nombre: Ana PÃ©rez 92.0
# Bueno
# Nombre: Carlos Mora 78.0
# Suficiente
# Nombre: MarÃ­a GonzÃ¡lez 65.0
# Bueno
# Nombre: Luis JimÃ©nez 88.0
# Reporobado
# Nombre: SofÃ­a Rojas 55.0
# Suficiente
# Nombre: Diego Castro 73.0
# Excelente
# Nombre: Valentina Herrera 96.0
# Bueno
# Nombre: AndrÃ©s Vargas 82.0
# Reporobado
# Nombre: Camila NÃºÃ±ez 47.0
# Suficiente
# Nombre: Roberto Alvarado 61.0
# Bueno
# Nombre: Patricia SolÃ­s 85.0
# Suficiente
# Nombre: Fernando Quesada 70.0
# Excelente
# Nombre: Laura MÃ©ndez 93.0
# Reporobado
# Nombre: Esteban Brenes 58.0
# Bueno
# Nombre: Daniela UreÃ±a 79.0
# Promedio del salón (desde archivo): 74.80

# %%
# Leemos notas_ejemplo.csv línea por línea
# Paso 1: abrimos el archivo con 'with open()'
# Paso 2: saltamos el encabezado con next()
# Paso 3: separamos cada línea con .split(",")
# Paso 4: acumulamos para el reporte

suma  = 0
total = 0
with open("notas_ejemplo.csv") as archivo:
    next(archivo)
    for linea in archivo:
        partes = linea.strip().split(",")
        nota   = float(partes[1])
        suma  += nota
        total += 1

print(f"Promedio del salón (desde archivo): {suma/total:.2f}")
# Out:
# Promedio del salón (desde archivo): 74.80

# %% [markdown]
# ### <mark>Ejercicio 4.1 — Construir lista y Top 3</mark>
#
# 1. Creamos una lista vacía `notas_salon = []`.
# 2. Usamos un bucle `for` y `append()` para agregar estas notas:
#    `92, 78, 65, 88, 55, 73, 96, 82, 47, 61`
# 3. Ordenamos la lista de **mayor a menor**.
# 4. Mostramos el **Top 3** usando slicing.
# 5. Mostramos también el promedio, el mínimo y el máximo.

# %%
# Fase 4 — Ejercicio 4.1
# Construye la lista con append, ordénala y muestra el Top 3.

#Respuesta

# %% [markdown]
# ---
#
# ## Fase 5 — Introducción a funciones
#
# ### 5.1 ¿Qué es una función?
#
# Una función es un bloque de código con nombre que podemos **reutilizar**:
#
# ```python
# def saludar(nombre):           # def nombre_funcion(parámetros):
#     print(f"Hola, {nombre}!") # cuerpo de la función
#
# saludar("Ana")                 # llamada: ejecuta el bloque
# saludar("Carlos")              # reutilización
# ```
#
# ### 5.2 return — devolver un resultado
#
# ```python
# def calcular_promedio(notas):
#     return sum(notas) / len(notas)
#
# promedio = calcular_promedio([85, 92, 74])
# print(f"Promedio: {promedio:.2f}")  # 83.67
# ```
#
# ### 5.3 ¿Por qué usar funciones?
#
# | Beneficio | Explicación |
# |-----------|-------------|
# | **Reutilización** | Escribimos el código una vez, lo usamos muchas veces |
# | **Legibilidad** | El código principal se vuelve más fácil de leer |
# | **Organización** | Separamos la lógica en partes pequeñas y claras |
#
# > En las Semanas 09–13 **todas** las aplicaciones usarán funciones.
# > Esta fase es nuestro puente.
#
# **Ejemplo:**

# %%
def saludar(parametro):           # def nombre_funcion(parámetros):
    print(f"Hola, {parametro}!") # cuerpo de la función

nombre = input("Ingrese su nombre: ")
saludar(nombre)                 # llamada: ejecuta el bloque
saludar("Carlos")              # reutilización
# Out:
# Hola, cris!
# Hola, Carlos!

# %%
# Ejemplo: función para clasificar una nota
def clasificar_nota(nota):  #Funcion para clasificar nota
    """Retorna la categoría de la nota."""
    if nota >= 90:
        return"Excelente"
    elif nota >= 75:
        return "Bueno"
    elif nota >= 60:
        return "Suficiente"
    else:
        return "Reprobado"


# Usar la función con varias notas

#Traer informacion del archi csv
with open("notas_ejemplo.csv") as archivo:
    next(archivo)
    for linea in archivo:
        partes = linea.strip().split(",") #parate el archivo e indica la cantidad de columnas del archivo
        nota   = float(partes[1]) #indica que va a trabajar con la segunda columna (notas)
        nombres = partes[0] #lista de nombres
        print(f"Nombre: {nombres } {nota} ")
# Out:
# Nombre: Ana PÃ©rez 92.0
# Nombre: Carlos Mora 78.0
# Nombre: MarÃ­a GonzÃ¡lez 65.0
# Nombre: Luis JimÃ©nez 88.0
# Nombre: SofÃ­a Rojas 55.0
# Nombre: Diego Castro 73.0
# Nombre: Valentina Herrera 96.0
# Nombre: AndrÃ©s Vargas 82.0
# Nombre: Camila NÃºÃ±ez 47.0
# Nombre: Roberto Alvarado 61.0
# Nombre: Patricia SolÃ­s 85.0
# Nombre: Fernando Quesada 70.0
# Nombre: Laura MÃ©ndez 93.0
# Nombre: Esteban Brenes 58.0
# Nombre: Daniela UreÃ±a 79.0

# %% [markdown]
# ### <mark>Ejercicio 5.1 — Funciones del sistema de notas</mark>
#
# Definimos dos funciones y las aplicamos con el archivo CSV:
#
# **Función 1 — `clasificar_nota(nota)`:**
# Recibe un número y retorna la categoría: `"Excelente"`, `"Bueno"`, `"Suficiente"` o `"Reprobado"`.
#
# **Función 2 — `reporte_salon(lista_notas)`:**
# Recibe una lista de notas y muestra:
# - Promedio del salón
# - Cantidad de aprobados y reprobados
# - Nota más alta y nota más baja
#
# **Aplicación:** Leemos `notas_ejemplo.csv`, clasificamos cada estudiante con `clasificar_nota()`
# y llamamos a `reporte_salon()` con todas las notas.
#
# **Salida esperada (extracto):**
# ```
# Ana Pérez: 92 → Excelente
# Carlos Mora: 78 → Bueno
# ...
# ==============================
#      REPORTE DEL SALÓN
# ==============================
# ...
# ```

# %%
# Fase 5 — Ejercicio 5.1
# Define clasificar_nota(nota) y reporte_salon(lista_notas).
def clasificar_nota(nota):  #Funcion para clasificar nota
    """Retorna la categoría de la nota."""
    if nota >= 90:
        return "Excelente"
    elif nota >= 75:
        return "Bueno"
    elif nota >= 60:
        return "Suficiente"
    else:
        return "Reprobado"
    
def reporte_salon(lista_notas):
    longitud = 38
    print("=" * longitud)
    print("Reporte del Salon".center(longitud))
    print("=" * longitud)
    
    #inicializar variables para contadores
    aprobado = 0
    reprobado = 0
    #cantidad de aprobados y reporbados
    for n in lista_notas:
        if n >= 70:
            aprobado +=1
        else:
            reprobado += 1

    #Calculo del promedio de notas
    #promedio = sum(lista_notas) / len(lista_notas)
    
    #Promedio general del salon
    #print(f"El promdio general del salon es: {promedio:.2f}")   
    print(f"El promdio general del salon es: {sum(lista_notas) / len(lista_notas)}")  

    #Aprobados y reprobados
    print(f"Cantidad de estudiantes aprobados: {aprobado}")
    print(f"Cantidad de estudiantes reprobados: {reprobado}")

    #Nota minima y maxima
    print(f"Nota minima:  {min(lista_notas)}")
    print(f"Nota maxima:  {max(lista_notas)}")



#Traer informacion del archi csv, se crean dos liosta vacias para poder llenarlas y usarlas en donde el programa requiera
nombre_lista = []
notas_lista = []

with open("notas_ejemplo.csv") as archivo:
    next(archivo)
    for linea in archivo:
        partes = linea.strip().split(",") #parate el archivo e indica la cantidad de columnas del archivo
        nombres = partes[0] #lista de nombres
        nota   = float(partes[1]) #indica que va a trabajar con la segunda columna (notas)
        print(f" {nombres } {nota} -> {clasificar_nota(nota)} ") #se imprime listado de estudiante - nota - cateegoria
        
        #Guardamos datos en lista para ser usados en el reporte salon
        nombre_lista.append(nombres)
        notas_lista.append(nota)
        
        
#Respuesta
    reporte_salon(notas_lista)
# Out:
#  Ana PÃ©rez 92.0 -> Excelente
#  Carlos Mora 78.0 -> Bueno
#  MarÃ­a GonzÃ¡lez 65.0 -> Suficiente
#  Luis JimÃ©nez 88.0 -> Bueno
#  SofÃ­a Rojas 55.0 -> Reprobado
#  Diego Castro 73.0 -> Suficiente
#  Valentina Herrera 96.0 -> Excelente
#  AndrÃ©s Vargas 82.0 -> Bueno
#  Camila NÃºÃ±ez 47.0 -> Reprobado
#  Roberto Alvarado 61.0 -> Suficiente
#  Patricia SolÃ­s 85.0 -> Bueno
#  Fernando Quesada 70.0 -> Suficiente
#  Laura MÃ©ndez 93.0 -> Excelente
#  Esteban Brenes 58.0 -> Reprobado
#  Daniela UreÃ±a 79.0 -> Bueno
# ======================================
#           Reporte del Salon
# ======================================
# El promdio general del salon es: 74.8
# Cantidad de estudiantes aprobados: 10
# Cantidad de estudiantes reprobados: 5
# Nota minima:  47.0
# Nota maxima:  96.0

# %% [markdown]
# ---
#
# ## ¿Qué sigue?
#
# ✅ **Lo que ya sabemos hacer:**
# - Tomar decisiones con `if-elif-else` y validar entradas con `try-except`
# - Repetir acciones con `for` y acumuladores
# - Crear menús interactivos con `while True + break`
# - Guardar colecciones con listas y manipularlas con métodos
# - Organizar código en funciones reutilizables con `def` y `return`
# - Leer datos de un archivo externo con `open()`
#
# 🔜 **Próxima semana (Semana 07):**
# - Listas anidadas y slicing avanzado
# - Tuplas y conjuntos
# - Colecciones más poderosas: **diccionarios**
# - Datos del mundo real: leer un archivo JSON con la biblioteca `json`
